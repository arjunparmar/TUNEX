# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt 
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
import cv2
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint

# %%
def read_pickle(directory):
    f = open(directory,"rb")
    X = pickle.load(f)
    return np.array(X)

# %%
base_dir = '/content/drive/Shareddrives/TUNEX/'

X_train = read_pickle(base_dir+'X_Train.pickle')/255.0
y_train = read_pickle(base_dir+"y_Train.pickle")
X_val = read_pickle(base_dir+'X_val.pickle')/255.0
y_val = read_pickle(base_dir+"y_val.pickle")

# %%
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1], X_train.shape[2], -1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1], X_val.shape[2], -1)

# %%
print(y_val)
# Out:
# [6 5 0 ... 6 0 0]

# %%
nb_classes = 7

model = Sequential()

model.add(Conv2D(64,(3,3), padding='same', input_shape=(48, 48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(nb_classes, activation='softmax'))

opt = Adam(lr=0.0001)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
checkpoint_filepath = "/content/drive/MyDrive/Model/FER/1"
checkpoint = ModelCheckpoint(filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)
callbacks_list = [checkpoint]

history = model.fit(
    X_train, y_train,
    epochs = 40,
    validation_data=(X_val, y_val),
    batch_size = 64,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/40
# 451/451 [==============================] - 36s 62ms/step - loss: 2.1350 - accuracy: 0.2043 - val_loss: 1.9078 - val_accuracy: 0.2617
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 2/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.8937 - accuracy: 0.2570 - val_loss: 1.7149 - val_accuracy: 0.3245
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 3/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.7613 - accuracy: 0.3169 - val_loss: 1.6473 - val_accuracy: 0.3798
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 4/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.6672 - accuracy: 0.3586 - val_loss: 1.6609 - val_accuracy: 0.3807
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 5/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.6027 - accuracy: 0.3796 - val_loss: 1.5410 - val_accuracy: 0.4158
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 6/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.5421 - accuracy: 0.4025 - val_loss: 1.4932 - val_accuracy: 0.4353
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 7/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.4898 - accuracy: 0.4238 - val_loss: 1.4896 - val_accuracy: 0.4407
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 8/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.4173 - accuracy: 0.4533 - val_loss: 1.3298 - val_accuracy: 0.4900
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 9/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.3846 - accuracy: 0.4664 - val_loss: 1.3404 - val_accuracy: 0.4939
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 10/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.3310 - accuracy: 0.4904 - val_loss: 1.2240 - val_accuracy: 0.5365
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 11/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.2991 - accuracy: 0.5105 - val_loss: 1.2313 - val_accuracy: 0.5321
# Epoch 12/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.2717 - accuracy: 0.5137 - val_loss: 1.3117 - val_accuracy: 0.5110
# Epoch 13/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.2390 - accuracy: 0.5280 - val_loss: 1.1576 - val_accuracy: 0.5599
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 14/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.2153 - accuracy: 0.5329 - val_loss: 1.2362 - val_accuracy: 0.5422
# Epoch 15/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.1928 - accuracy: 0.5471 - val_loss: 1.1431 - val_accuracy: 0.5623
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 16/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.1704 - accuracy: 0.5579 - val_loss: 1.1302 - val_accuracy: 0.5722
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 17/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.1423 - accuracy: 0.5631 - val_loss: 1.1349 - val_accuracy: 0.5747
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 18/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.1233 - accuracy: 0.5745 - val_loss: 1.0981 - val_accuracy: 0.5834
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 19/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.1039 - accuracy: 0.5787 - val_loss: 1.1021 - val_accuracy: 0.5801
# Epoch 20/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.0887 - accuracy: 0.5891 - val_loss: 1.0961 - val_accuracy: 0.5853
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 21/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.0633 - accuracy: 0.5941 - val_loss: 1.0713 - val_accuracy: 0.5977
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 22/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.0453 - accuracy: 0.6062 - val_loss: 1.0842 - val_accuracy: 0.6033
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 23/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.0379 - accuracy: 0.6053 - val_loss: 1.0428 - val_accuracy: 0.6142
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 24/40
# 451/451 [==============================] - 26s 59ms/step - loss: 1.0097 - accuracy: 0.6215 - val_loss: 1.0620 - val_accuracy: 0.6015
# Epoch 25/40
# 451/451 [==============================] - 27s 59ms/step - loss: 1.0075 - accuracy: 0.6209 - val_loss: 1.0666 - val_accuracy: 0.6074
# Epoch 26/40
# 451/451 [==============================] - 26s 59ms/step - loss: 0.9882 - accuracy: 0.6293 - val_loss: 1.0358 - val_accuracy: 0.6111
# Epoch 27/40
# 451/451 [==============================] - 27s 60ms/step - loss: 0.9722 - accuracy: 0.6298 - val_loss: 1.0211 - val_accuracy: 0.6267
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 28/40
# 451/451 [==============================] - 27s 59ms/step - loss: 0.9438 - accuracy: 0.6464 - val_loss: 1.0348 - val_accuracy: 0.6245
# Epoch 29/40
# 451/451 [==============================] - 27s 59ms/step - loss: 0.9510 - accuracy: 0.6423 - val_loss: 1.0225 - val_accuracy: 0.6252
# Epoch 30/40
# 451/451 [==============================] - 27s 59ms/step - loss: 0.9290 - accuracy: 0.6499 - val_loss: 1.0147 - val_accuracy: 0.6269
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 31/40
# 451/451 [==============================] - 27s 59ms/step - loss: 0.9052 - accuracy: 0.6608 - val_loss: 1.0116 - val_accuracy: 0.6332
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 32/40
# 451/451 [==============================] - 27s 59ms/step - loss: 0.8959 - accuracy: 0.6625 - val_loss: 1.0289 - val_accuracy: 0.6204
# Epoch 33/40
# 451/451 [==============================] - 27s 59ms/step - loss: 0.8798 - accuracy: 0.6691 - val_loss: 1.0537 - val_accuracy: 0.6233
# Epoch 34/40
# 451/451 [==============================] - 26s 58ms/step - loss: 0.8703 - accuracy: 0.6740 - val_loss: 1.0096 - val_accuracy: 0.6354
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 35/40
# 451/451 [==============================] - 27s 59ms/step - loss: 0.8469 - accuracy: 0.6801 - val_loss: 1.0214 - val_accuracy: 0.6308
# Epoch 36/40
# 451/451 [==============================] - 26s 59ms/step - loss: 0.8500 - accuracy: 0.6809 - val_loss: 1.0270 - val_accuracy: 0.6261
# Epoch 37/40
# 451/451 [==============================] - 26s 59ms/step - loss: 0.8210 - accuracy: 0.6944 - val_loss: 1.0185 - val_accuracy: 0.6333
# Epoch 38/40
# 451/451 [==============================] - 27s 59ms/step - loss: 0.7984 - accuracy: 0.7043 - val_loss: 1.0070 - val_accuracy: 0.6436
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 39/40
# 451/451 [==============================] - 27s 59ms/step - loss: 0.7970 - accuracy: 0.7031 - val_loss: 0.9815 - val_accuracy: 0.6496
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model/FER/1/assets
# Epoch 40/40
# 451/451 [==============================] - 27s 59ms/step - loss: 0.7670 - accuracy: 0.7107 - val_loss: 1.0241 - val_accuracy: 0.6421

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
